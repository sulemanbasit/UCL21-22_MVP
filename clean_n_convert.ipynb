# %%
import pandas as pd

# %% [markdown]
# ## Read Player Data

# %%
player_data = pd.read_csv("player_data_202502101344.csv")
club_data = pd.read_csv('club_ks_att_go_df_dis_atm_gl_dsc_202502060055.csv')

# %%
player_data.head()
# Out:
#        player_name         club    position  minutes_played  match_played  \
# 0         Courtois  Real Madrid  Goalkeeper            1230            13
# 1  Vinícius Júnior  Real Madrid     Forward            1199            13
# 2          Benzema  Real Madrid     Forward            1106            12
# 3           Modrić  Real Madrid  Midfielder            1077            13
# 4     Éder Militão  Real Madrid    Defender            1076            12
#
#    goals  assists  distance_covered  corner_taken  offsides  ...  headers  \
# 0      0        0              64.2           NaN       NaN  ...      NaN
# 1      4        6             133.0           3.0       4.0  ...      0.0
# 2     15        1             121.5           2.0       9.0  ...      3.0
# 3      0        4             124.5          10.0       0.0  ...      NaN
# 4      0        0             110.4           NaN       NaN  ...      NaN
#
#    penalties  others  inside_area  outside_areas  saved  saved_penalties  \
# ...

# %%
player_data.describe()
# Out:
#        minutes_played  match_played        goals      assists  \
# count     1000.000000   1000.000000  1000.000000  1000.000000
# mean       342.827000      5.203000     0.429000     0.364000
# std        238.900239      2.640599     1.167185     0.822302
# min          1.000000      1.000000     0.000000     0.000000
# 25%        142.000000      3.000000     0.000000     0.000000
# 50%        326.000000      5.000000     0.000000     0.000000
# 75%        500.000000      7.000000     0.000000     0.000000
# max       1230.000000     13.000000    15.000000     7.000000
#
#        distance_covered  corner_taken    offsides    dribbles     tackles  \
# count       1000.000000    328.000000  328.000000  328.000000  887.000000
# mean          39.560500      2.158537    0.762195    6.341463    5.310034
# std           27.217944      5.028286    1.789753    8.747521    4.816701
# min            0.200000      0.000000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ## Clean Data

# %%
duplicates = player_data[player_data.duplicated(subset=["player_name",'club'],keep=False)]
duplicates.describe()
# Out:
#        minutes_played  match_played       goals     assists  distance_covered  \
# count      284.000000    284.000000  284.000000  284.000000        284.000000
# mean       369.169014      5.471831    0.239437    0.323944         42.738732
# std        209.690432      2.415187    0.503410    0.757057         24.609719
# min         18.000000      1.000000    0.000000    0.000000          3.300000
# 25%        180.000000      4.000000    0.000000    0.000000         21.600000
# 50%        347.000000      5.500000    0.000000    0.000000         39.300000
# 75%        540.000000      8.000000    0.000000    0.000000         66.600000
# max        867.000000     10.000000    2.000000    4.000000         96.300000
#
#        corner_taken  offsides    dribbles     tackles       t_won  ...  \
# count    156.000000     156.0  156.000000  284.000000  284.000000  ...
# mean       0.820513       0.0    3.333333    6.549296    2.478873  ...
# ...

# %%
clean_player_data = player_data.drop_duplicates(subset=['player_name', 'club'], keep='first')

# %%
clean_player_data.describe()
# Out:
#        minutes_played  match_played       goals     assists  distance_covered  \
# count      745.000000    745.000000  745.000000  745.000000        745.000000
# mean       332.491275      5.100671    0.493960    0.377181         38.268456
# std        248.123209      2.716796    1.314836    0.846412         27.988625
# min          1.000000      1.000000    0.000000    0.000000          0.200000
# 25%        117.000000      3.000000    0.000000    0.000000         14.300000
# 50%        303.000000      5.000000    0.000000    0.000000         34.600000
# 75%        493.000000      7.000000    0.000000    0.000000         56.400000
# max       1230.000000     13.000000   15.000000    7.000000        133.000000
#
#        corner_taken    offsides    dribbles     tackles       t_won  ...  \
# count    183.000000  183.000000  183.000000  632.000000  632.000000  ...
# mean       3.256831    1.366120    8.792350    4.729430    2.087025  ...
# ...

# %%
clean_filled_player_data = clean_player_data.fillna(0)
clean_filled_player_data.describe()
# Out:
#        minutes_played  match_played       goals     assists  distance_covered  \
# count      745.000000    745.000000  745.000000  745.000000        745.000000
# mean       332.491275      5.100671    0.493960    0.377181         38.268456
# std        248.123209      2.716796    1.314836    0.846412         27.988625
# min          1.000000      1.000000    0.000000    0.000000          0.200000
# 25%        117.000000      3.000000    0.000000    0.000000         14.300000
# 50%        303.000000      5.000000    0.000000    0.000000         34.600000
# 75%        493.000000      7.000000    0.000000    0.000000         56.400000
# max       1230.000000     13.000000   15.000000    7.000000        133.000000
#
#        corner_taken   offsides    dribbles     tackles       t_won  ...  \
# count    745.000000  745.00000  745.000000  745.000000  745.000000  ...
# mean       0.800000    0.33557    2.159732    4.012081    1.770470  ...
# ...

# %% [markdown]
# # Add Data

# %% [markdown]
# ## Convert Data
